# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("titanic-passengers.csv", sep = ";")

# %%
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.isnull(data).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age']=data['Age'].fillna(data['Age'].median())
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data['Embarked']=data['Embarked'].fillna(data['Embarked'].mode()[0])
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop('Cabin', axis=1, inplace=True)

# %%
pd.isnull(data).sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( data )

# %%
dics={"Yes":1 , "No":0} 
data['Survived']=data['Survived'].replace(dics)
dicss={"male":1 , "female": 0}
data['Sex']=data['Sex'].replace(dicss)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
data.groupby(['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
data['title']=data['Name'].apply(lambda x:x.split(',')[1].split('.')[0].strip())
data.drop('Name', axis=1, inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343         0       2    1  28.0      0      0      248740
# 1             76         0       3    1  25.0      0      0      348123
# 2            641         0       3    1  20.0      0      0      350050
# 3            568         0       3    0  29.0      0      4      349909
# 4            672         0       1    1  31.0      1      0  F.C. 12750
# ..           ...       ...     ...  ...   ...    ...    ...         ...
# 886           10         1       2    0  14.0      1      0      237736
# 887           61         0       3    1  22.0      0      0        2669
# 888          535         0       3    0  30.0      0      0      315084
# 889          102         0       3    1  28.0      0      0      349215
# 890          428         1       2    0  19.0      0      0      250655
#
#         Fare Embarked title
# 0    13.0000        S    Mr
# 1     7.6500        S    Mr
# ...

# %%
g=sns.FacetGrid(data,col='title')
g.map(plt.hist,'Age')

# %%
g=sns.FacetGrid(data,col='title')
g.map(plt.hist,'Sex')

# %%
g=sns.FacetGrid(data,col='title')
g.map(plt.hist,'Pclass')

# %%
TDd = { "Capt" : "Officer",
                      "Col" : "Officer",
                    "Major" : "Officer",
                      "Dr" : "Officer",
                    "Rev" : "Officer",
                    "Jonkheer" : "Royalty",
                    "Don" : "Royalty",
                    "Sir" : "Royalty",
                   "Lady" : "Royalty" ,
                  "the Countess" : "Royalty",
                    "Dona" : "Royalty" ,
                    "Mme" : "Miss",
                    "Mlle" : "Miss",
                    "Miss" : "Miss",
                    "Ms" : "Mrs",
                    "Mr" : "Mrs" ,
                    "Mrs" : "Mrs" ,
                    "Master" : "Master"
                    }
data['title1']= data['title'].replace(TDd) 
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343         0       2    1  28.0      0      0      248740
# 1             76         0       3    1  25.0      0      0      348123
# 2            641         0       3    1  20.0      0      0      350050
# 3            568         0       3    0  29.0      0      4      349909
# 4            672         0       1    1  31.0      1      0  F.C. 12750
# ..           ...       ...     ...  ...   ...    ...    ...         ...
# 886           10         1       2    0  14.0      1      0      237736
# 887           61         0       3    1  22.0      0      0        2669
# 888          535         0       3    0  30.0      0      0      315084
# 889          102         0       3    1  28.0      0      0      349215
# 890          428         1       2    0  19.0      0      0      250655
#
#         Fare Embarked title title1
# 0    13.0000        S    Mr    Mrs
# ...

# %%
g=sns.FacetGrid(data,col='title1')
g.map(plt.hist,'Age')
g=sns.FacetGrid(data,col='title1')
g.map(plt.hist,'Sex')
g=sns.FacetGrid(data,col='title1')
g.map(plt.hist,'Pclass')

# %%
dgrp=data.groupby('title1').mean()
dgrp
# Out:
#          PassengerId  Survived    Pclass       Sex        Age     SibSp  \
# title1
# Master    414.975000  0.575000  2.625000  1.000000   6.916750  2.300000
# Miss      411.567568  0.702703  2.286486  0.000000  23.021622  0.702703
# Mrs       454.222395  0.281493  2.329705  0.804044  32.030327  0.367030
# Officer   545.055556  0.277778  1.444444  0.944444  45.666667  0.333333
# Royalty   554.200000  0.600000  1.000000  0.600000  41.600000  0.400000
#
#             Parch       Fare  FamilySize
# title1
# Master   1.375000  34.703125    4.675000
# Miss     0.540541  44.104416    2.243243
# Mrs      0.284603  28.447283    1.651633
# Officer  0.111111  35.786344    1.444444
# Royalty  0.000000  42.150000    1.400000

# %%
dgrp.reset_index(inplace=True)
dgrp
# Out:
#     title1  PassengerId  Survived    Pclass       Sex        Age     SibSp  \
# 0   Master   414.975000  0.575000  2.625000  1.000000   6.916750  2.300000
# 1     Miss   411.567568  0.702703  2.286486  0.000000  23.021622  0.702703
# 2      Mrs   454.222395  0.281493  2.329705  0.804044  32.030327  0.367030
# 3  Officer   545.055556  0.277778  1.444444  0.944444  45.666667  0.333333
# 4  Royalty   554.200000  0.600000  1.000000  0.600000  41.600000  0.400000
#
#       Parch       Fare  FamilySize
# 0  1.375000  34.703125    4.675000
# 1  0.540541  44.104416    2.243243
# 2  0.284603  28.447283    1.651633
# 3  0.111111  35.786344    1.444444
# 4  0.000000  42.150000    1.400000

# %%
sns.barplot(x='title1', y='Survived' , data=dgrp, order=dgrp.sort_values('Survived').title1)
plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %%
dataset

# %%
data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343         0       2    1  28.0      0      0      248740
# 1             76         0       3    1  25.0      0      0      348123
# 2            641         0       3    1  20.0      0      0      350050
# 3            568         0       3    0  29.0      0      4      349909
# 4            672         0       1    1  31.0      1      0  F.C. 12750
# ..           ...       ...     ...  ...   ...    ...    ...         ...
# 886           10         1       2    0  14.0      1      0      237736
# 887           61         0       3    1  22.0      0      0        2669
# 888          535         0       3    0  30.0      0      0      315084
# 889          102         0       3    1  28.0      0      0      349215
# 890          428         1       2    0  19.0      0      0      250655
#
#         Fare Embarked title title1  FamilySize
# 0    13.0000        S    Mr    Mrs           1
# ...
